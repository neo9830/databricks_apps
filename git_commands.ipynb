# %%
# %sh
cd /Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry

ls -la

echo "====Git Status====="
git -c safe.directory=/Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry status

# %%
# %sh
cd /Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry

echo "====Adding all files to git===="
git -c safe.directory=/Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry add .

echo ""
echo "✅ Files staged:"
git -c safe.directory=/Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry status --short

# %%
# %sh
cd /Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry

echo "====Committing changes===="
git -c safe.directory=/Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry \
    -c user.email="sagnik.sarkar1704@gmail.com" \
    -c user.name="Sagnik Sarkar" \
    commit -m "Add Streamlit data entry app with dual forms"

echo ""
echo "✅ Commit successful!"

# %%
# %sh
cd /Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry

echo "====Pushing to GitHub===="
git -c safe.directory=/Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry push origin master

echo ""
echo "✅ Pushed to GitHub successfully!"
echo "Check: https://github.com/neo9830/databricks_apps"
