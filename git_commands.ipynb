# %%
# %sh
cd /Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry

# %%
# %sh
cd /Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry

# Initialize git repository
git init

# Configure git user (replace with your details)
git config user.email "sagnik.sarkar1704@gmail.com"
git config user.name "Sagnik Sarkar"

# Add remote repository (replace with your repo URL)
git remote add origin https://github.com/neo9830/databricks_apps.git

echo "Git initialized successfully!"
git status

# %%
# %sh
cd /Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry

# Fix the dubious ownership warning by skipping the safe directory check
export GIT_CONFIG_NOSYSTEM=1

echo "Git config set to skip ownership check!"
echo ""
echo "Now checking git status:"
git status

# %%
# %sh
# Clone your existing repository
# Replace with your actual repository URL

# Example for HTTPS:
# git clone https://github.com/yourusername/your-repo.git /Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry

# Example for SSH:
# git clone git@github.com:yourusername/your-repo.git /Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry

echo "Note: Uncomment and update the git clone command above with your repository URL"

# %%
# %sh
cd /Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry

# Add all files (bypassing ownership check)
git -c safe.directory=/Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry add .

echo "Files staged for commit:"
git -c safe.directory=/Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry status --short

# %%
# %sh
cd /Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry

# Commit with message (bypassing ownership check)
git -c safe.directory=/Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry commit -m "Add Streamlit data entry app with dual forms"

echo ""
echo "Commit created successfully!"

# %%
# %sh
cd /Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry

# Push to remote (bypassing ownership check)
git -c safe.directory=/Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry push origin main

# If main doesn't work, try:
# git -c safe.directory=/Workspace/Users/sagnik.sarkar1704@gmail.com/project_data_entry push origin master
